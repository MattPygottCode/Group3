# %% [markdown]
# # Project Planning Document
#
# ### Key deadlines:
#
# Week 8 beginning 10th November:
# - Met at 2-5pm on Tuesday
# - Project set-up and planning
# - Getting to understand and start coding sections 1 and 2
# - This is also our last week of the normal mathematical programming tutorial
#
# Week 9 beginning 17th November:
# - Meeting at 11-12pm and 4-5pm on Tuesday
# - Aim to get core sections 1-4 completed by the end of the week
# - Thoroughly explain and discuss code in Jupyter notebook as we go along
#
# Week 10 beginning 24th November:
# - TBC
# - TBC
#
# Week 11 beginning 1st December:
# - TBC
# - Full project due on Wednesday morning
#
# ### Task breakdown:
#
# Sections 1: Matt
#
# Sections 2: Bo and Kabir
#
# Section 3: TBC
#
# Section 4: TBC
#
# Extension (5/6/7): TBC
#
# ### Other Ideas:
#
# **Collaborating coding tools:**
#
# - We're planning to all use Github and Visual Studio Code to edit and share our code.
#
# - Please ask for help if you are struggling with these tools.
#
# **Task management tools:**
#
# - We thinking of using excel spreadsheet to list tasks, deadlines and who completed them.
#
# - Excel link for tasks: https://docs.google.com/spreadsheets/d/1oS0quzfqXyGIA9sFu5PjXXK4FV-di4D9JVFiSI4uRsA/edit?usp=sharing
#
# **Variable naming:**
#
# - Variable names should contain only lowercase letters unless necessary eg matrix M can have a capital.
#
# - Words should be separated by an underscore e.g. user_id
#
# **Comments and functions:**
#
# - Remember to write comments thoughout your code and on each function
#
# - Write your code in lowercase and save uppercase for comments
#
# - Functions should be contained in a separate file to the main notebook

# %% [markdown]
# # Project Planning Document
#
# ### Key deadlines:
#
# Week 8 beginning 10th November:
# - Met at 2-5pm on Tuesday
# - Project set-up and planning
# - Getting to understand and start coding sections 1 and 2
# - This is also our last week of the normal mathematical programming tutorial
#
# Week 9 beginning 17th November:
# - Meeting at 3-5pm on Tuesday to share progress
# - Aim to get core sections 1-4 completed by the end of the week
# - Thoroughly explain and discuss code in Jupyter notebook as we go along
#
# Week 10 beginning 24th November:
# - ?
# - ?
#
# Week 11 beginning 1st December:
# - Full project due on Wednesday morning!
# - Shall we aim to have it done by Monday?
#
# ### Task breakdown:
#
# Sections 1 and 2: everyone
#
# Section 3: TBC
#
# Section 4: TBC
#
# Extension (5/6/7): TBC
#
# ### Other Ideas:
#
# **Collaborating coding tools:**
#
# - We're planning to all use Github and Visual Studio Code to edit and share our code.
#
# - Please ask for help if you are struggling with these tools.
#
# **Task management tools:**
#
# - We thinking of using excel spreadsheet to list tasks, deadlines and who completed them.
#
# - Excel link for tasks: https://docs.google.com/spreadsheets/d/1oS0quzfqXyGIA9sFu5PjXXK4FV-di4D9JVFiSI4uRsA/edit?usp=sharing
#
# **Variable naming:**
#
# - Variable names should contain only lowercase letters unless necessary eg matrix M can have a capital.
#
# - Words should be separated by an underscore e.g. user_id
#
# **Comments and functions:**
#
# - Remember to write comments thoughout your code and on each function
#
# - Write your code in lowercase and save uppercase for comments
#
# - Functions should be contained in a separate file to the main notebook
